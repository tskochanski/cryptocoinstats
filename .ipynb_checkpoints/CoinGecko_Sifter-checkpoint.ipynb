# %%
import pandas as pd
import requests
import bs4
from bs4 import BeautifulSoup
import re, os
import random
import time
import datetime
now = datetime.datetime.now()
dateStr = now.strftime('%Y-%m-%d')
print(dateStr)

url_0 = 'https://www.coingecko.com/en?page='
url_1 = 'https://www.coingecko.com/en/coins/'

header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}
# Out:
# 2021-01-10

# %%
pd.set_option('mode.chained_assignment', None)

url_A = pd.DataFrame()
x = range(1,2)
for n in x:
    r = requests.get(url_0 + str(n), headers=header)    
    dfs = pd.read_html(r.text)
    for df in dfs:
        df['CoinA']=''
        for m in range(len(df)):
            if (len(df.Coin[m].split()) < 4):
                df['CoinA'][m] = url_1 + df.Coin[m].split()[0]
            else:
                df['CoinA'][m] = url_1 + df.Coin[m].split()[0] + '-' + df.Coin[m].split()[1]
    url_A = url_A.append(df, ignore_index = True)
    time.sleep(random.randrange(2,6))
# print(url_A)

# %%
url_A['happyness'] = ''
url_A['likers'] = ''
x = range(len(url_A))
# x = range(3)

for n in x:    
    r = requests.get(url_A.CoinA[n].lower(), headers=header)
    soup = BeautifulSoup(r.text, 'html.parser')
    progress = soup.findAll('div', {'class': 'progress-bar bg-success'} )
    stars = soup.findAll('span', {'data-controller': 'portfolios'} )
    prog_text = []
    stars_text = []
    for x in progress:
        prog_text.append(str(x))
    raw_txt=(str(prog_text))
    pp3=(raw_txt[1:len(raw_txt)-1]) 
    for x in stars:
        stars_text.append(str(x))
    raw_txt2=(str(stars_text))
    pp3B=(raw_txt2[1:len(raw_txt2)-1]) 
    
    
    try:
        url_A['happyness'].loc[n] = re.search(r'(?<=width:)(.*)(?=\"\>)', pp3).group(1).strip()       
        url_A['likers'].loc[n] = re.search(r'((\d+)|(\d+\,\d+))(?=\speople like this)', pp3B).group(1).strip().replace(',', '')
    except: 
        print('error - ',url_A['Coin'].loc[n],url_A['#'].loc[n] )    
    time.sleep(random.randrange(2,6))
# Out:
# error -  Celsius Network  CEL  CEL 22
# error -  Synthetix Network Token  SNX  SNX 23
# error -  Crypto.com Coin  CRO  CRO 24
# error -  cETH  CETH  CETH 35
# error -  yearn.finance  YFI  YFI 39
# error -  cUSDC  CUSDC  CUSDC 45
# error -  Reserve Rights Token  RSR  RSR 66
# error -  Basic Attention Token  BAT  BAT 70
# error -  Empty Set Dollar  ESD  ESD 75
# error -  TrueUSD  TUSD  TUSD 82
# error -  HUSD  HUSD  HUSD 83
# error -  Energy Web Token  EWT  EWT 90

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(url_A[['CoinA', 'happyness', 'likers']].sort_values('likers', ascending=True))
# Out:
#                                                 CoinA happyness  likers
# 34            https://www.coingecko.com/en/coins/cETH
# 23  https://www.coingecko.com/en/coins/Crypto.com-...
# 74       https://www.coingecko.com/en/coins/Empty-Set
# 69  https://www.coingecko.com/en/coins/Basic-Atten...
# 81         https://www.coingecko.com/en/coins/TrueUSD
# 82            https://www.coingecko.com/en/coins/HUSD
# 22  https://www.coingecko.com/en/coins/Synthetix-N...
# 65  https://www.coingecko.com/en/coins/Reserve-Rights
# 21  https://www.coingecko.com/en/coins/Celsius-Net...
# 89      https://www.coingecko.com/en/coins/Energy-Web
# 38   https://www.coingecko.com/en/coins/yearn.finance
# 44           https://www.coingecko.com/en/coins/cUSDC
# 37            https://www.coingecko.com/en/coins/cDAI     75.0%    1015
# 79       https://www.coingecko.com/en/coins/THORChain    91.38%   10283
# 83    https://www.coingecko.com/en/coins/Bitcoin-Gold    88.81%   10947
# 96            https://www.coingecko.com/en/coins/Lisk     82.0%   11008
# 71            https://www.coingecko.com/en/coins/ICON    94.12%   11197
# 61            https://www.coingecko.com/en/coins/Nano    73.36%   11290
# 60        https://www.coingecko.com/en/coins/Loopring    88.16%   11406
# 52          https://www.coingecko.com/en/coins/Elrond    90.75%   11967
# 26           https://www.coingecko.com/en/coins/Maker    83.63%   12124
# 57          https://www.coingecko.com/en/coins/renBTC    88.89%    1236
# 84      https://www.coingecko.com/en/coins/Ampleforth     62.5%   12614
# 91         https://www.coingecko.com/en/coins/Siacoin    80.77%   14006
# 33       https://www.coingecko.com/en/coins/LEO-Token    71.43%    1484
# 53           https://www.coingecko.com/en/coins/Sushi    77.91%   15167
# 51          https://www.coingecko.com/en/coins/Kusama    86.79%   15250
# 47        https://www.coingecko.com/en/coins/Compound    81.36%   15463
# 50           https://www.coingecko.com/en/coins/Waves    81.54%   15584
# 87           https://www.coingecko.com/en/coins/Verge     91.1%   15636
# 67       https://www.coingecko.com/en/coins/The-Graph    80.36%   15693
# 88   https://www.coingecko.com/en/coins/Kyber-Network    89.58%   16200
# 70              https://www.coingecko.com/en/coins/0x    86.67%   16372
# 19   https://www.coingecko.com/en/coins/Theta-Network    86.11%   17045
# 72        https://www.coingecko.com/en/coins/Algorand    88.07%   17049
# 1         https://www.coingecko.com/en/coins/Ethereum    89.97%  173888
# 28            https://www.coingecko.com/en/coins/Aave     86.3%   17445
# 55     https://www.coingecko.com/en/coins/OMG-Network    84.51%   17732
# 59  https://www.coingecko.com/en/coins/Paxos-Standard    100.0%    1869
# 63        https://www.coingecko.com/en/coins/DigiByte    91.67%   19174
# 73             https://www.coingecko.com/en/coins/REN    92.38%   19207
# 25          https://www.coingecko.com/en/coins/Cosmos    86.44%   19726
# 17             https://www.coingecko.com/en/coins/NEM    78.95%   19769
# 92   https://www.coingecko.com/en/coins/Band-Protocol    83.16%   20140
# 0          https://www.coingecko.com/en/coins/Bitcoin    76.28%  204544
# 20             https://www.coingecko.com/en/coins/OKB    77.78%    2200
# 43         https://www.coingecko.com/en/coins/Zilliqa     92.4%   23338
# 18           https://www.coingecko.com/en/coins/Tezos    93.01%   23617
# 35            https://www.coingecko.com/en/coins/IOTA    90.46%   24091
# 14             https://www.coingecko.com/en/coins/EOS    78.65%   24615
# 2           https://www.coingecko.com/en/coins/Tether    52.21%   24647
# 42           https://www.coingecko.com/en/coins/Zcash    80.47%   25508
# 27             https://www.coingecko.com/en/coins/NEO    86.71%   25763
# 49       https://www.coingecko.com/en/coins/Huobi-BTC    16.67%     261
# 36     https://www.coingecko.com/en/coins/Binance-USD    83.33%    2666
# 41  https://www.coingecko.com/en/coins/Ethereum-Cl...    85.81%   27280
# 39     https://www.coingecko.com/en/coins/Huobi-Token     75.0%    2814
# 64            https://www.coingecko.com/en/coins/Near    94.74%    3166
# 13  https://www.coingecko.com/en/coins/Wrapped-Bit...    66.67%    3285
# 24         https://www.coingecko.com/en/coins/VeChain    91.71%   34801
# 10    https://www.coingecko.com/en/coins/Binance-Coin    82.78%   35740
# 31         https://www.coingecko.com/en/coins/Uniswap    86.05%   37513
# 29            https://www.coingecko.com/en/coins/Dash    87.14%   37551
# 46       https://www.coingecko.com/en/coins/FTX-Token    70.59%    3875
# 16            https://www.coingecko.com/en/coins/TRON    85.15%   38940
# 98  https://www.coingecko.com/en/coins/Bitcoin-Dia...    86.55%    3950
# 15          https://www.coingecko.com/en/coins/Monero    88.55%   40620
# 32        https://www.coingecko.com/en/coins/Dogecoin    81.16%   43780
# 5     https://www.coingecko.com/en/coins/Bitcoin-Cash    80.55%   45947
# 68    https://www.coingecko.com/en/coins/Bitcoin-Cash    80.39%   45951
# 66           https://www.coingecko.com/en/coins/Terra    73.91%    4653
# 9          https://www.coingecko.com/en/coins/Stellar    83.77%   47319
# 7         https://www.coingecko.com/en/coins/Polkadot    85.71%   47639
# 95        https://www.coingecko.com/en/coins/Aave-ETH      0.0%     502
# 97           https://www.coingecko.com/en/coins/Quant    93.55%    5206
# 56       https://www.coingecko.com/en/coins/Avalanche    78.52%    5284
# 99            https://www.coingecko.com/en/coins/IOST    89.53%    5496
# 6          https://www.coingecko.com/en/coins/Cardano    91.44%   58926
# 77    https://www.coingecko.com/en/coins/Nexus-Mutual    57.89%    5951
# 8        https://www.coingecko.com/en/coins/Chainlink    91.68%   60263
# 40        https://www.coingecko.com/en/coins/Filecoin    81.82%    6221
# 90          https://www.coingecko.com/en/coins/Status    83.33%    6312
# 94         https://www.coingecko.com/en/coins/Horizen    88.24%    6380
# 80  https://www.coingecko.com/en/coins/Hedera-Hash...    72.84%    6533
# 11      https://www.coingecko.com/en/coins/Bitcoin-SV    70.47%    6789
# 62      https://www.coingecko.com/en/coins/Blockstack    89.47%    7010
# 48          https://www.coingecko.com/en/coins/Decred    85.71%    7082
# 75            https://www.coingecko.com/en/coins/NEXO     90.0%    7123
# 4         https://www.coingecko.com/en/coins/Litecoin    83.56%   74608
# 54             https://www.coingecko.com/en/coins/UMA     80.0%    7467
# 12        https://www.coingecko.com/en/coins/USD-Coin    76.92%    7794
# 85       https://www.coingecko.com/en/coins/SwissBorg    77.08%    7992
# 58        https://www.coingecko.com/en/coins/Ontology    82.14%    8262
# 30             https://www.coingecko.com/en/coins/Dai     75.0%    8361
# 45          https://www.coingecko.com/en/coins/Solana    72.22%    8526
# 93        https://www.coingecko.com/en/coins/Balancer    96.55%    8666
# 86      https://www.coingecko.com/en/coins/BitTorrent    87.88%    8703
# 78       https://www.coingecko.com/en/coins/Aave-LINK    57.14%     875
# 76            https://www.coingecko.com/en/coins/Qtum    87.18%    9657
# 3              https://www.coingecko.com/en/coins/XRP    73.66%   97193

# %%
print(url_A[['CoinA', 'happyness', 'likers']].sort_values('happyness', ascending=False))
# Out:
#                                                 CoinA happyness  likers
# 93        https://www.coingecko.com/en/coins/Balancer    96.55%    8666
# 64            https://www.coingecko.com/en/coins/Near    94.74%    3166
# 71            https://www.coingecko.com/en/coins/ICON    94.12%   11197
# 97           https://www.coingecko.com/en/coins/Quant    93.55%    5206
# 18           https://www.coingecko.com/en/coins/Tezos    93.01%   23617
# 43         https://www.coingecko.com/en/coins/Zilliqa     92.4%   23338
# 73             https://www.coingecko.com/en/coins/REN    92.38%   19207
# 24         https://www.coingecko.com/en/coins/VeChain    91.71%   34801
# 8        https://www.coingecko.com/en/coins/Chainlink    91.68%   60263
# 63        https://www.coingecko.com/en/coins/DigiByte    91.67%   19174
# 6          https://www.coingecko.com/en/coins/Cardano    91.44%   58926
# 79       https://www.coingecko.com/en/coins/THORChain    91.38%   10283
# 87           https://www.coingecko.com/en/coins/Verge     91.1%   15636
# 52          https://www.coingecko.com/en/coins/Elrond    90.75%   11967
# 35            https://www.coingecko.com/en/coins/IOTA    90.46%   24091
# 75            https://www.coingecko.com/en/coins/NEXO     90.0%    7123
# 1         https://www.coingecko.com/en/coins/Ethereum    89.97%  173888
# 88   https://www.coingecko.com/en/coins/Kyber-Network    89.58%   16200
# 99            https://www.coingecko.com/en/coins/IOST    89.53%    5496
# 62      https://www.coingecko.com/en/coins/Blockstack    89.47%    7010
# 57          https://www.coingecko.com/en/coins/renBTC    88.89%    1236
# 83    https://www.coingecko.com/en/coins/Bitcoin-Gold    88.81%   10947
# 15          https://www.coingecko.com/en/coins/Monero    88.55%   40620
# 94         https://www.coingecko.com/en/coins/Horizen    88.24%    6380
# 60        https://www.coingecko.com/en/coins/Loopring    88.16%   11406
# 72        https://www.coingecko.com/en/coins/Algorand    88.07%   17049
# 86      https://www.coingecko.com/en/coins/BitTorrent    87.88%    8703
# 76            https://www.coingecko.com/en/coins/Qtum    87.18%    9657
# 29            https://www.coingecko.com/en/coins/Dash    87.14%   37551
# 51          https://www.coingecko.com/en/coins/Kusama    86.79%   15250
# 27             https://www.coingecko.com/en/coins/NEO    86.71%   25763
# 70              https://www.coingecko.com/en/coins/0x    86.67%   16372
# 98  https://www.coingecko.com/en/coins/Bitcoin-Dia...    86.55%    3950
# 25          https://www.coingecko.com/en/coins/Cosmos    86.44%   19726
# 28            https://www.coingecko.com/en/coins/Aave     86.3%   17445
# 19   https://www.coingecko.com/en/coins/Theta-Network    86.11%   17045
# 31         https://www.coingecko.com/en/coins/Uniswap    86.05%   37513
# 41  https://www.coingecko.com/en/coins/Ethereum-Cl...    85.81%   27280
# 7         https://www.coingecko.com/en/coins/Polkadot    85.71%   47639
# 48          https://www.coingecko.com/en/coins/Decred    85.71%    7082
# 16            https://www.coingecko.com/en/coins/TRON    85.15%   38940
# 55     https://www.coingecko.com/en/coins/OMG-Network    84.51%   17732
# 9          https://www.coingecko.com/en/coins/Stellar    83.77%   47319
# 26           https://www.coingecko.com/en/coins/Maker    83.63%   12124
# 4         https://www.coingecko.com/en/coins/Litecoin    83.56%   74608
# 90          https://www.coingecko.com/en/coins/Status    83.33%    6312
# 36     https://www.coingecko.com/en/coins/Binance-USD    83.33%    2666
# 92   https://www.coingecko.com/en/coins/Band-Protocol    83.16%   20140
# 10    https://www.coingecko.com/en/coins/Binance-Coin    82.78%   35740
# 58        https://www.coingecko.com/en/coins/Ontology    82.14%    8262
# 96            https://www.coingecko.com/en/coins/Lisk     82.0%   11008
# 40        https://www.coingecko.com/en/coins/Filecoin    81.82%    6221
# 50           https://www.coingecko.com/en/coins/Waves    81.54%   15584
# 47        https://www.coingecko.com/en/coins/Compound    81.36%   15463
# 32        https://www.coingecko.com/en/coins/Dogecoin    81.16%   43780
# 91         https://www.coingecko.com/en/coins/Siacoin    80.77%   14006
# 5     https://www.coingecko.com/en/coins/Bitcoin-Cash    80.55%   45947
# 42           https://www.coingecko.com/en/coins/Zcash    80.47%   25508
# 68    https://www.coingecko.com/en/coins/Bitcoin-Cash    80.39%   45951
# 67       https://www.coingecko.com/en/coins/The-Graph    80.36%   15693
# 54             https://www.coingecko.com/en/coins/UMA     80.0%    7467
# 17             https://www.coingecko.com/en/coins/NEM    78.95%   19769
# 14             https://www.coingecko.com/en/coins/EOS    78.65%   24615
# 56       https://www.coingecko.com/en/coins/Avalanche    78.52%    5284
# 53           https://www.coingecko.com/en/coins/Sushi    77.91%   15167
# 20             https://www.coingecko.com/en/coins/OKB    77.78%    2200
# 85       https://www.coingecko.com/en/coins/SwissBorg    77.08%    7992
# 12        https://www.coingecko.com/en/coins/USD-Coin    76.92%    7794
# 0          https://www.coingecko.com/en/coins/Bitcoin    76.28%  204544
# 30             https://www.coingecko.com/en/coins/Dai     75.0%    8361
# 39     https://www.coingecko.com/en/coins/Huobi-Token     75.0%    2814
# 37            https://www.coingecko.com/en/coins/cDAI     75.0%    1015
# 66           https://www.coingecko.com/en/coins/Terra    73.91%    4653
# 3              https://www.coingecko.com/en/coins/XRP    73.66%   97193
# 61            https://www.coingecko.com/en/coins/Nano    73.36%   11290
# 80  https://www.coingecko.com/en/coins/Hedera-Hash...    72.84%    6533
# 45          https://www.coingecko.com/en/coins/Solana    72.22%    8526
# 33       https://www.coingecko.com/en/coins/LEO-Token    71.43%    1484
# 46       https://www.coingecko.com/en/coins/FTX-Token    70.59%    3875
# 11      https://www.coingecko.com/en/coins/Bitcoin-SV    70.47%    6789
# 13  https://www.coingecko.com/en/coins/Wrapped-Bit...    66.67%    3285
# 84      https://www.coingecko.com/en/coins/Ampleforth     62.5%   12614
# 77    https://www.coingecko.com/en/coins/Nexus-Mutual    57.89%    5951
# 78       https://www.coingecko.com/en/coins/Aave-LINK    57.14%     875
# 2           https://www.coingecko.com/en/coins/Tether    52.21%   24647
# 49       https://www.coingecko.com/en/coins/Huobi-BTC    16.67%     261
# 59  https://www.coingecko.com/en/coins/Paxos-Standard    100.0%    1869
# 95        https://www.coingecko.com/en/coins/Aave-ETH      0.0%     502
# 34            https://www.coingecko.com/en/coins/cETH
# 74       https://www.coingecko.com/en/coins/Empty-Set
# 65  https://www.coingecko.com/en/coins/Reserve-Rights
# 82            https://www.coingecko.com/en/coins/HUSD
# 22  https://www.coingecko.com/en/coins/Synthetix-N...
# 89      https://www.coingecko.com/en/coins/Energy-Web
# 23  https://www.coingecko.com/en/coins/Crypto.com-...
# 44           https://www.coingecko.com/en/coins/cUSDC
# 21  https://www.coingecko.com/en/coins/Celsius-Net...
# 81         https://www.coingecko.com/en/coins/TrueUSD
# 38   https://www.coingecko.com/en/coins/yearn.finance
# 69  https://www.coingecko.com/en/coins/Basic-Atten...

# %%
url_A.to_csv('data_out\\' + dateStr + '.csv', index = False)
